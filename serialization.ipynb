# %%
from person import Person

# %%
p = Person(first_name = "Sulabh", last_name="Srivastava", age = "40")

# Check dictinary pertaining to the Pydsntic model
p.__dict__
# Out:
# {'first_name': 'Sulabh', 'last_name': 'Srivastava', 'age': 40}

# %%
# Serialize into Python Dictionary
p.model_dump()
# Out:
# {'first_name': 'Sulabh', 'last_name': 'Srivastava', 'age': 40}

# %%
type(p.model_dump())
# Out:
# dict

# %%
# Serialize into Python string
p.model_dump_json()
# Out:
# '{"first_name":"Sulabh","last_name":"Srivastava","age":40}'

# %%
type(p.model_dump_json())
# Out:
# str
